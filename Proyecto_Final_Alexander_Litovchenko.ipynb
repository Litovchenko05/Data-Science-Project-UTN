# %% [markdown]
# El tema que se va a abordar en este proyecto es el precio de los teléfonos móviles.
# Se va a intentar responder a la pregunta de si es correcto el precio que se esta pagando por un celular a juzgar por sus caracteristicas técnicas.

# %% [markdown]
# La idea es que personas que no tengan mucha noción de celulares pueden comparar el precio al que se les esta vendiendo el dispositivo con el precio que, en base a sus caracteristicas, en teoría este deberia tener y así poder buscar otras alternativas.

# %%
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
data = pd.read_csv("/content/mobile phone specifications.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# 1         Yes          1080          2400          8  ...         64.0
# 2         Yes          1242          2688          6  ...         12.0
# 3         Yes           828          1792          6  ...         12.0
# 4         Yes          1080          2340          8  ...         12.0
#
#    Front camera  Operating system  Wi-Fi Bluetooth  GPS Number of SIMs   3G  \
# 0          16.0           Android    Yes       Yes  Yes              2  Yes
# 1          16.0           Android    Yes       Yes  Yes              2  Yes
# 2          12.0               iOS    Yes       Yes  Yes              2  Yes
# 3          12.0               iOS    Yes       Yes  Yes              2  Yes
# 4          32.0           Android    Yes       Yes  Yes              1   No
#
#    4G/ LTE   Price
# 0      Yes   58998
# 1      Yes   27999
# 2      Yes  106900
# 3      Yes   62900
# 4       No   49990
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (1359, 22)

# %%
data.dtypes
# Out:
# Unnamed: 0                  int64
# Name                       object
# Brand                      object
# Model                      object
# Battery capacity (mAh)      int64
# Screen size (inches)      float64
# Touchscreen                object
# Resolution x                int64
# Resolution y                int64
# Processor                   int64
# RAM (MB)                    int64
# Internal storage (GB)     float64
# Rear camera               float64
# Front camera              float64
# Operating system           object
# Wi-Fi                      object
# Bluetooth                  object
# GPS                        object
# Number of SIMs              int64
# 3G                         object
# 4G/ LTE                    object
# Price                       int64
# dtype: object

# %%
data["Price"].mean()
# Out:
# 11465.825607064018

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Brand                     0
# Model                     0
# Battery capacity (mAh)    0
# Screen size (inches)      0
# Touchscreen               0
# Resolution x              0
# Resolution y              0
# Processor                 0
# RAM (MB)                  0
# Internal storage (GB)     0
# Rear camera               0
# Front camera              0
# Operating system          0
# Wi-Fi                     0
# Bluetooth                 0
# GPS                       0
# Number of SIMs            0
# 3G                        0
# 4G/ LTE                   0
# Price                     0
# dtype: int64

# %%
data["Touchscreen"].value_counts()
# Out:
# Yes    1342
# No       17
# Name: Touchscreen, dtype: int64

# %%
data["Operating system"].value_counts()
# Out:
# Android       1299
# Windows         19
# iOS             17
# Cyanogen        10
# BlackBerry      10
# Tizen            3
# Sailfish         1
# Name: Operating system, dtype: int64

# %%
data.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
data
# Out:
#                                 Name     Brand                   Model  \
# 0     OnePlus 7T Pro McLaren Edition   OnePlus  7T Pro McLaren Edition
# 1                      Realme X2 Pro    Realme                  X2 Pro
# 2                  iPhone 11 Pro Max     Apple       iPhone 11 Pro Max
# 3                          iPhone 11     Apple               iPhone 11
# 4                       LG G8X ThinQ        LG               G8X ThinQ
# ...                              ...       ...                     ...
# 1354                   Intex Aqua A2     Intex                 Aqua A2
# 1355     Videocon Infinium Z51 Nova+  Videocon      Infinium Z51 Nova+
# 1356                   Intex Aqua Y4     Intex                 Aqua Y4
# 1357                 iBall Andi4 B20     iBall               Andi4 B20
# 1358             iBall Andi Avonte 5     iBall           Andi Avonte 5
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                       4085                  6.67         Yes          1440
# 1                       4000                  6.50         Yes          1080
# 2                       3969                  6.50         Yes          1242
# 3                       3110                  6.10         Yes           828
# 4                       4000                  6.40         Yes          1080
# ...                      ...                   ...         ...           ...
# 1354                    1500                  4.00         Yes           480
# 1355                    2000                  5.00         Yes           480
# 1356                    1700                  4.50         Yes           480
# 1357                    1250                  4.00         Yes           480
# 1358                    2150                  5.00         Yes           480
#
#       Resolution y  Processor  RAM (MB)  ...  Rear camera  Front camera  \
# 0             3120          8     12000  ...         48.0          16.0
# 1             2400          8      6000  ...         64.0          16.0
# 2             2688          6      4000  ...         12.0          12.0
# 3             1792          6      4000  ...         12.0          12.0
# 4             2340          8      6000  ...         12.0          32.0
# ...            ...        ...       ...  ...          ...           ...
# 1354           800          4       512  ...          5.0           0.3
# 1355           854          4      1000  ...          8.0           5.0
# 1356           854          2       512  ...          5.0           2.0
# 1357           800          1       256  ...          2.0           0.3
# 1358           854          4      1000  ...          8.0           0.0
#
#       Operating system Wi-Fi Bluetooth  GPS Number of SIMs   3G 4G/ LTE  \
# 0              Android   Yes       Yes  Yes              2  Yes     Yes
# 1              Android   Yes       Yes  Yes              2  Yes     Yes
# 2                  iOS   Yes       Yes  Yes              2  Yes     Yes
# 3                  iOS   Yes       Yes  Yes              2  Yes     Yes
# 4              Android   Yes       Yes  Yes              1   No      No
# ...                ...   ...       ...  ...            ...  ...     ...
# 1354           Android   Yes       Yes  Yes              2  Yes      No
# 1355           Android   Yes       Yes  Yes              2  Yes      No
# 1356           Android   Yes       Yes   No              2  Yes      No
# 1357           Android   Yes       Yes  Yes              2  Yes      No
# 1358           Android   Yes       Yes  Yes              2  Yes      No
#
#        Price
# 0      58998
# 1      27999
# 2     106900
# 3      62900
# 4      49990
# ...      ...
# 1354    2599
# 1355    2940
# 1356    2999
# 1357    2498
# 1358    3999
#
# [1359 rows x 21 columns]

# %%
data.drop(columns = ["Name", "Brand", "Model"], inplace = True)

# %%
data
# Out:
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                       4085                  6.67         Yes          1440
# 1                       4000                  6.50         Yes          1080
# 2                       3969                  6.50         Yes          1242
# 3                       3110                  6.10         Yes           828
# 4                       4000                  6.40         Yes          1080
# ...                      ...                   ...         ...           ...
# 1354                    1500                  4.00         Yes           480
# 1355                    2000                  5.00         Yes           480
# 1356                    1700                  4.50         Yes           480
# 1357                    1250                  4.00         Yes           480
# 1358                    2150                  5.00         Yes           480
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 0             3120          8     12000                256.000         48.0
# 1             2400          8      6000                 64.000         64.0
# 2             2688          6      4000                 64.000         12.0
# 3             1792          6      4000                 64.000         12.0
# 4             2340          8      6000                128.000         12.0
# ...            ...        ...       ...                    ...          ...
# 1354           800          4       512                  8.000          5.0
# 1355           854          4      1000                  8.000          8.0
# 1356           854          2       512                  4.000          5.0
# 1357           800          1       256                  0.512          2.0
# 1358           854          4      1000                  8.000          8.0
#
#       Front camera Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G  \
# 0             16.0          Android   Yes       Yes  Yes               2  Yes
# 1             16.0          Android   Yes       Yes  Yes               2  Yes
# 2             12.0              iOS   Yes       Yes  Yes               2  Yes
# 3             12.0              iOS   Yes       Yes  Yes               2  Yes
# 4             32.0          Android   Yes       Yes  Yes               1   No
# ...            ...              ...   ...       ...  ...             ...  ...
# 1354           0.3          Android   Yes       Yes  Yes               2  Yes
# 1355           5.0          Android   Yes       Yes  Yes               2  Yes
# 1356           2.0          Android   Yes       Yes   No               2  Yes
# 1357           0.3          Android   Yes       Yes  Yes               2  Yes
# 1358           0.0          Android   Yes       Yes  Yes               2  Yes
#
#      4G/ LTE   Price
# 0        Yes   58998
# 1        Yes   27999
# 2        Yes  106900
# 3        Yes   62900
# 4         No   49990
# ...      ...     ...
# 1354      No    2599
# 1355      No    2940
# 1356      No    2999
# 1357      No    2498
# 1358      No    3999
#
# [1359 rows x 18 columns]

# %%
data["Wi-Fi"].value_counts()
# Out:
# Yes    1351
# No        8
# Name: Wi-Fi, dtype: int64

# %%
data["GPS"].value_counts()
# Out:
# Yes    1251
# No      108
# Name: GPS, dtype: int64

# %%
data.dtypes
# Out:
# Battery capacity (mAh)      int64
# Screen size (inches)      float64
# Touchscreen                object
# Resolution x                int64
# Resolution y                int64
# Processor                   int64
# RAM (MB)                    int64
# Internal storage (GB)     float64
# Rear camera               float64
# Front camera              float64
# Operating system           object
# Wi-Fi                      object
# Bluetooth                  object
# GPS                        object
# Number of SIMs              int64
# 3G                         object
# 4G/ LTE                    object
# Price                       int64
# dtype: object

# %%
data_prueba_replace = data["Operating system"].replace({"Cyanogen" : "Others", "BlackBerry" : "Others", "Tizen" : "Others", "Sailfish" : "Others"})

# %%
data_prueba_replace.value_counts()
# Out:
# Android    1299
# Others       24
# Windows      19
# iOS          17
# Name: Operating system, dtype: int64

# %%
data['Operating system'] = data["Operating system"].replace({"Cyanogen" : "Others", "BlackBerry" : "Others", "Tizen" : "Others", "Sailfish" : "Others"})

# %%
data["Operating system"].value_counts()
# Out:
# Android    1299
# Others       24
# Windows      19
# iOS          17
# Name: Operating system, dtype: int64

# %%
sns.countplot(data["Operating system"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.sample(10)
# Out:
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 878                     2500                  5.00         Yes           720
# 1156                    2500                  5.00         Yes           720
# 310                     3000                  5.65         Yes           720
# 1283                    2910                  5.50         Yes           720
# 1241                    2500                  5.50         Yes           720
# 853                     1800                  4.00         Yes           480
# 993                     3200                  5.50         Yes          1440
# 237                     2070                  4.50         Yes           720
# 1352                    2100                  5.00         Yes           854
# 646                     2600                  5.00         Yes           540
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 878           1280          4      2000                   16.0          8.0
# 1156          1280          4      2000                   16.0          8.0
# 310           1440          4      3000                   16.0         13.0
# 1283          1280          4      1000                    8.0          8.0
# 1241          1280          4      3000                   16.0         13.0
# 853            800          4       512                    4.0          5.0
# 993           2560          8      3000                   32.0         16.0
# 237           1280          4      1000                    8.0          5.0
# 1352           480          4      1000                    8.0          8.0
# 646            960          8      1000                   16.0          5.0
#
#       Front camera Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G  \
# 878            5.0          Android   Yes       Yes  Yes               1  Yes
# 1156           5.0          Android   Yes       Yes  Yes               2  Yes
# 310           13.0          Android   Yes       Yes   No               2  Yes
# 1283           2.0          Android   Yes       Yes  Yes               2  Yes
# 1241           5.0          Android   Yes       Yes  Yes               2  Yes
# 853            2.0          Android   Yes       Yes   No               1  Yes
# 993            8.0          Android   Yes       Yes  Yes               1  Yes
# 237            1.3          Android   Yes       Yes  Yes               2  Yes
# 1352           2.0          Android   Yes       Yes  Yes               2  Yes
# 646            5.0          Android   Yes       Yes  Yes               2  Yes
#
#      4G/ LTE  Price
# 878      Yes   4610
# 1156     Yes   4990
# 310      Yes   8480
# 1283      No   8499
# 1241     Yes   4790
# 853      Yes   2599
# 993      Yes  11100
# 237       No   9999
# 1352      No   3699
# 646      Yes   5290

# %%
data["Price"] = data["Price"].apply(lambda x: x*0.012)

# %%
data.rename(columns = {"Price" : "Price (USD)"})
# Out:
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                       4085                  6.67         Yes          1440
# 1                       4000                  6.50         Yes          1080
# 2                       3969                  6.50         Yes          1242
# 3                       3110                  6.10         Yes           828
# 4                       4000                  6.40         Yes          1080
# ...                      ...                   ...         ...           ...
# 1354                    1500                  4.00         Yes           480
# 1355                    2000                  5.00         Yes           480
# 1356                    1700                  4.50         Yes           480
# 1357                    1250                  4.00         Yes           480
# 1358                    2150                  5.00         Yes           480
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 0             3120          8     12000                256.000         48.0
# 1             2400          8      6000                 64.000         64.0
# 2             2688          6      4000                 64.000         12.0
# 3             1792          6      4000                 64.000         12.0
# 4             2340          8      6000                128.000         12.0
# ...            ...        ...       ...                    ...          ...
# 1354           800          4       512                  8.000          5.0
# 1355           854          4      1000                  8.000          8.0
# 1356           854          2       512                  4.000          5.0
# 1357           800          1       256                  0.512          2.0
# 1358           854          4      1000                  8.000          8.0
#
#       Front camera Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G  \
# 0             16.0          Android   Yes       Yes  Yes               2  Yes
# 1             16.0          Android   Yes       Yes  Yes               2  Yes
# 2             12.0              iOS   Yes       Yes  Yes               2  Yes
# 3             12.0              iOS   Yes       Yes  Yes               2  Yes
# 4             32.0          Android   Yes       Yes  Yes               1   No
# ...            ...              ...   ...       ...  ...             ...  ...
# 1354           0.3          Android   Yes       Yes  Yes               2  Yes
# 1355           5.0          Android   Yes       Yes  Yes               2  Yes
# 1356           2.0          Android   Yes       Yes   No               2  Yes
# 1357           0.3          Android   Yes       Yes  Yes               2  Yes
# 1358           0.0          Android   Yes       Yes  Yes               2  Yes
#
#      4G/ LTE  Price (USD)
# 0        Yes      707.976
# 1        Yes      335.988
# 2        Yes     1282.800
# 3        Yes      754.800
# 4         No      599.880
# ...      ...          ...
# 1354      No       31.188
# 1355      No       35.280
# 1356      No       35.988
# 1357      No       29.976
# 1358      No       47.988
#
# [1359 rows x 18 columns]

# %%
data["Touchscreen"] = data["Touchscreen"].apply(lambda x: 1 if x=="Yes" else 0)
data["Wi-Fi"] = data["Wi-Fi"].apply(lambda x: 1 if x=="Yes" else 0)
data["Bluetooth"] = data["Bluetooth"].apply(lambda x: 1 if x=="Yes" else 0)
data["GPS"] = data["GPS"].apply(lambda x: 1 if x=="Yes" else 0)
data["3G"] = data["3G"].apply(lambda x: 1 if x=="Yes" else 0)
data["4G/ LTE"] = data["4G/ LTE"].apply(lambda x: 1 if x=="Yes" else 0)

# %%
data.dtypes
# Out:
# Battery capacity (mAh)      int64
# Screen size (inches)      float64
# Touchscreen                 int64
# Resolution x                int64
# Resolution y                int64
# Processor                   int64
# RAM (MB)                    int64
# Internal storage (GB)     float64
# Rear camera               float64
# Front camera              float64
# Operating system           object
# Wi-Fi                       int64
# Bluetooth                   int64
# GPS                         int64
# Number of SIMs              int64
# 3G                          int64
# 4G/ LTE                     int64
# Price                     float64
# dtype: object

# %%
pd.get_dummies(data["Operating system"], prefix= "OS")
# Out:
#       OS_Android  OS_Others  OS_Windows  OS_iOS
# 0              1          0           0       0
# 1              1          0           0       0
# 2              0          0           0       1
# 3              0          0           0       1
# 4              1          0           0       0
# ...          ...        ...         ...     ...
# 1354           1          0           0       0
# 1355           1          0           0       0
# 1356           1          0           0       0
# 1357           1          0           0       0
# 1358           1          0           0       0
#
# [1359 rows x 4 columns]

# %%
dummies_OS = pd.get_dummies(data["Operating system"], prefix= "OS")

# %%
data = data.join(dummies_OS)

# %%
data.sample(8)
# Out:
#       Battery capacity (mAh)  Screen size (inches)  Touchscreen  Resolution x  \
# 1215                    2500                   5.0            0           720
# 956                     2800                   5.2            1           720
# 36                      3000                   5.8            1          1440
# 405                     2900                   5.5            1           720
# 893                     3000                   5.5            1          1080
# 153                     2000                   2.4            0           240
# 1160                    3300                   5.5            1           720
# 1233                    2200                   5.0            1           720
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 1215          1280          4      2000                   16.0          8.0
# 956           1280          8      3000                   16.0         13.0
# 36            2960          8      4000                   64.0         12.0
# 405           1280          8      2000                    8.0          8.0
# 893           1920          4      4000                   32.0         16.0
# 153            320          2       512                    4.0          2.0
# 1160          1080          8      2000                   16.0         13.0
# 1233          1280          4      1000                    8.0         13.0
#
#       Front camera  ... Bluetooth  GPS  Number of SIMs  3G  4G/ LTE    Price  \
# 1215           5.0  ...         1    1               2   1        0   43.188
# 956            5.0  ...         1    1               2   1        1  180.312
# 36             8.0  ...         1    1               2   1        1  323.988
# 405            5.0  ...         1    1               2   1        1   79.992
# 893           12.0  ...         1    1               1   1        1   77.388
# 153            0.3  ...         1    1               1   0        1   14.988
# 1160           5.0  ...         1    1               2   1        1  161.400
# 1233           5.0  ...         1    1               2   1        1   35.400
#
#       OS_Android  OS_Others  OS_Windows  OS_iOS
# 1215           1          0           0       0
# 956            1          0           0       0
# 36             1          0           0       0
# 405            1          0           0       0
# 893            1          0           0       0
# 153            0          1           0       0
# 1160           1          0           0       0
# 1233           1          0           0       0
#
# [8 rows x 22 columns]

# %%
data.dtypes
# Out:
# Battery capacity (mAh)      int64
# Screen size (inches)      float64
# Touchscreen                 int64
# Resolution x                int64
# Resolution y                int64
# Processor                   int64
# RAM (MB)                    int64
# Internal storage (GB)     float64
# Rear camera               float64
# Front camera              float64
# Operating system           object
# Wi-Fi                       int64
# Bluetooth                   int64
# GPS                         int64
# Number of SIMs              int64
# 3G                          int64
# 4G/ LTE                     int64
# Price                     float64
# OS_Android                  uint8
# OS_Others                   uint8
# OS_Windows                  uint8
# OS_iOS                      uint8
# dtype: object

# %%
data.drop(columns = "Operating system", inplace = True)

# %%
data.dtypes
# Out:
# Battery capacity (mAh)      int64
# Screen size (inches)      float64
# Touchscreen                 int64
# Resolution x                int64
# Resolution y                int64
# Processor                   int64
# RAM (MB)                    int64
# Internal storage (GB)     float64
# Rear camera               float64
# Front camera              float64
# Wi-Fi                       int64
# Bluetooth                   int64
# GPS                         int64
# Number of SIMs              int64
# 3G                          int64
# 4G/ LTE                     int64
# Price                     float64
# OS_Android                  uint8
# OS_Others                   uint8
# OS_Windows                  uint8
# OS_iOS                      uint8
# dtype: object

# %%
data.sample(10)
# Out:
#       Battery capacity (mAh)  Screen size (inches)  Touchscreen  Resolution x  \
# 624                     4000                  6.55            1           720
# 1155                    2500                  5.00            1           720
# 613                     4500                  6.70            1          1440
# 152                     4000                  5.99            1          1080
# 675                     4000                  6.19            1           720
# 1028                    2000                  5.00            1           720
# 1166                    1200                  4.00            1           480
# 1013                    3000                  5.50            1          1440
# 593                     3000                  5.86            1           720
# 601                     2650                  5.00            1           720
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 624           1600          8      4000                   64.0         16.0
# 1155          1280          4      1000                    8.0          5.0
# 613           3200          8      8000                  128.0         12.0
# 152           2160          8      3000                   32.0         12.0
# 675           1500          8      3000                   32.0         13.0
# 1028          1280          4      1000                    8.0          8.0
# 1166           800          2       512                    4.0          2.0
# 1013          2560          4      4000                   32.0         21.0
# 593           1520          4      2000                   16.0         13.0
# 601           1280          4      2000                   16.0         13.0
#
#       Front camera  ...  Bluetooth  GPS  Number of SIMs  3G  4G/ LTE    Price  \
# 624            8.0  ...          1    1               2   1        1  119.520
# 1155           2.0  ...          1    1               2   1        0   32.280
# 613           10.0  ...          1    1               2   1        1  887.988
# 152            5.0  ...          1    1               2   1        1  104.388
# 675            8.0  ...          1    0               2   1        1   83.880
# 1028           2.0  ...          1    1               2   0        1   83.880
# 1166           0.3  ...          1    1               2   1        0   23.988
# 1013           8.0  ...          1    1               1   1        1  203.988
# 593            5.0  ...          1    1               2   1        1   53.988
# 601            5.0  ...          1    1               2   1        1   55.188
#
#       OS_Android  OS_Others  OS_Windows  OS_iOS
# 624            1          0           0       0
# 1155           1          0           0       0
# 613            1          0           0       0
# 152            1          0           0       0
# 675            1          0           0       0
# 1028           1          0           0       0
# 1166           1          0           0       0
# 1013           1          0           0       0
# 593            1          0           0       0
# 601            1          0           0       0
#
# [10 rows x 21 columns]

# %%
data.corr()
# Out:
#                         Battery capacity (mAh)  Screen size (inches)  \
# Battery capacity (mAh)                1.000000              0.746886
# Screen size (inches)                  0.746886              1.000000
# Touchscreen                           0.118693              0.156484
# Resolution x                          0.495362              0.590146
# Resolution y                          0.573969              0.709646
# Processor                             0.538017              0.631984
# RAM (MB)                              0.600969              0.707088
# Internal storage (GB)                 0.483489              0.612804
# Rear camera                           0.499756              0.581909
# Front camera                          0.540250              0.651781
# Wi-Fi                                 0.000252             -0.016046
# Bluetooth                             0.028047              0.031690
# GPS                                   0.006549              0.037301
# Number of SIMs                        0.040151              0.037657
# 3G                                   -0.084751             -0.061548
# 4G/ LTE                               0.299965              0.276154
# Price                                 0.297525              0.402462
# OS_Android                            0.159993              0.190163
# OS_Others                            -0.122897             -0.235596
# OS_Windows                           -0.090659             -0.081944
# OS_iOS                               -0.054305              0.014282
#
#                         Touchscreen  Resolution x  Resolution y  Processor  \
# Battery capacity (mAh)     0.118693      0.495362      0.573969   0.538017
# Screen size (inches)       0.156484      0.590146      0.709646   0.631984
# Touchscreen                1.000000      0.110885      0.144616   0.109661
# Resolution x               0.110885      1.000000      0.920780   0.583203
# Resolution y               0.144616      0.920780      1.000000   0.642540
# Processor                  0.109661      0.583203      0.642540   1.000000
# RAM (MB)                   0.103383      0.687661      0.771964   0.615097
# Internal storage (GB)      0.070374      0.544791      0.640653   0.481688
# Rear camera                0.092661      0.506104      0.600198   0.468668
# Front camera               0.085684      0.467119      0.585385   0.556287
# Wi-Fi                     -0.008661      0.030297      0.017221   0.028076
# Bluetooth                 -0.011890      0.024807      0.026446   0.042555
# GPS                        0.040365      0.093022      0.087486   0.020472
# Number of SIMs             0.056120     -0.171891     -0.134961   0.039891
# 3G                         0.068327      0.023374      0.000790  -0.044597
# 4G/ LTE                    0.070743      0.328109      0.340140   0.253804
# Price                      0.050460      0.540711      0.576152   0.302492
# OS_Android                 0.072496      0.025065      0.048635   0.202394
# OS_Others                 -0.135707     -0.075334     -0.114010  -0.148148
# OS_Windows                 0.013402     -0.013046     -0.027030  -0.121223
# OS_iOS                     0.012668      0.056730      0.073770  -0.070463
#
#                         RAM (MB)  Internal storage (GB)  Rear camera  \
# Battery capacity (mAh)  0.600969               0.483489     0.499756
# Screen size (inches)    0.707088               0.612804     0.581909
# Touchscreen             0.103383               0.070374     0.092661
# Resolution x            0.687661               0.544791     0.506104
# Resolution y            0.771964               0.640653     0.600198
# Processor               0.615097               0.481688     0.468668
# RAM (MB)                1.000000               0.847864     0.661602
# Internal storage (GB)   0.847864               1.000000     0.572591
# Rear camera             0.661602               0.572591     1.000000
# Front camera            0.696881               0.613574     0.639652
# Wi-Fi                   0.022606               0.030531     0.025337
# Bluetooth               0.024635               0.033525     0.028387
# GPS                     0.020426              -0.008765     0.009423
# Number of SIMs         -0.023896              -0.015116    -0.038466
# 3G                     -0.054904              -0.074836    -0.020256
# 4G/ LTE                 0.324121               0.188652     0.234148
# Price                   0.613446               0.644079     0.379120
# OS_Android              0.090089               0.047525     0.057388
# OS_Others              -0.077371              -0.069348    -0.069004
# OS_Windows             -0.080965              -0.040457    -0.013756
# OS_iOS                  0.010707               0.037079    -0.009765
#
#                         Front camera  ...  Bluetooth       GPS  \
# Battery capacity (mAh)      0.540250  ...   0.028047  0.006549
# Screen size (inches)        0.651781  ...   0.031690  0.037301
# Touchscreen                 0.085684  ...  -0.011890  0.040365
# Resolution x                0.467119  ...   0.024807  0.093022
# Resolution y                0.585385  ...   0.026446  0.087486
# Processor                   0.556287  ...   0.042555  0.020472
# RAM (MB)                    0.696881  ...   0.024635  0.020426
# Internal storage (GB)       0.613574  ...   0.033525 -0.008765
# Rear camera                 0.639652  ...   0.028387  0.009423
# Front camera                1.000000  ...   0.000637  0.035795
# Wi-Fi                       0.029505  ...   0.268070  0.119645
# Bluetooth                   0.000637  ...   1.000000  0.073118
# GPS                         0.035795  ...   0.073118  1.000000
# Number of SIMs              0.054066  ...  -0.028119  0.043897
# 3G                         -0.086578  ...   0.077554  0.180446
# 4G/ LTE                     0.242562  ...   0.035049  0.083753
# Price                       0.310672  ...   0.027999  0.066807
# OS_Android                  0.125208  ...  -0.022705 -0.010174
# OS_Others                  -0.100502  ...   0.014165 -0.022570
# OS_Windows                 -0.093534  ...   0.012580  0.011816
# OS_iOS                     -0.013514  ...   0.011890  0.033070
#
#                         Number of SIMs        3G   4G/ LTE     Price  \
# Battery capacity (mAh)        0.040151 -0.084751  0.299965  0.297525
# Screen size (inches)          0.037657 -0.061548  0.276154  0.402462
# Touchscreen                   0.056120  0.068327  0.070743  0.050460
# Resolution x                 -0.171891  0.023374  0.328109  0.540711
# Resolution y                 -0.134961  0.000790  0.340140  0.576152
# Processor                     0.039891 -0.044597  0.253804  0.302492
# RAM (MB)                     -0.023896 -0.054904  0.324121  0.613446
# Internal storage (GB)        -0.015116 -0.074836  0.188652  0.644079
# Rear camera                  -0.038466 -0.020256  0.234148  0.379120
# Front camera                  0.054066 -0.086578  0.242562  0.310672
# Wi-Fi                         0.017207  0.129190  0.043177  0.028506
# Bluetooth                    -0.028119  0.077554  0.035049  0.027999
# GPS                           0.043897  0.180446  0.083753  0.066807
# Number of SIMs                1.000000  0.241241  0.118540 -0.162491
# 3G                            0.241241  1.000000  0.355163 -0.003769
# 4G/ LTE                       0.118540  0.355163  1.000000  0.149792
# Price                        -0.162491 -0.003769  0.149792  1.000000
# OS_Android                    0.277719 -0.027866  0.005585 -0.159845
# OS_Others                    -0.119531 -0.026045 -0.023984 -0.024267
# OS_Windows                   -0.214983  0.041153 -0.045254  0.045051
# OS_iOS                       -0.144555  0.038898  0.065906  0.276613
#
#                         OS_Android  OS_Others  OS_Windows    OS_iOS
# Battery capacity (mAh)    0.159993  -0.122897   -0.090659 -0.054305
# Screen size (inches)      0.190163  -0.235596   -0.081944  0.014282
# Touchscreen               0.072496  -0.135707    0.013402  0.012668
# Resolution x              0.025065  -0.075334   -0.013046  0.056730
# Resolution y              0.048635  -0.114010   -0.027030  0.073770
# Processor                 0.202394  -0.148148   -0.121223 -0.070463
# RAM (MB)                  0.090089  -0.077371   -0.080965  0.010707
# Internal storage (GB)     0.047525  -0.069348   -0.040457  0.037079
# Rear camera               0.057388  -0.069004   -0.013756 -0.009765
# Front camera              0.125208  -0.100502   -0.093534 -0.013514
# Wi-Fi                    -0.016538   0.010318    0.009163  0.008661
# Bluetooth                -0.022705   0.014165    0.012580  0.011890
# GPS                      -0.010174  -0.022570    0.011816  0.033070
# Number of SIMs            0.277719  -0.119531   -0.214983 -0.144555
# 3G                       -0.027866  -0.026045    0.041153  0.038898
# 4G/ LTE                   0.005585  -0.023984   -0.045254  0.065906
# Price                    -0.159845  -0.024267    0.045051  0.276613
# OS_Android                1.000000  -0.623870   -0.554056 -0.523693
# OS_Others                -0.623870   1.000000   -0.015966 -0.015091
# OS_Windows               -0.554056  -0.015966    1.000000 -0.013402
# OS_iOS                   -0.523693  -0.015091   -0.013402  1.000000
#
# [21 rows x 21 columns]

# %%
sns.displot(data["Price"], kind = "kde")
plt.savefig("Histograma Precio.jpg")

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(data=data, x="Price" , y="Internal storage (GB)", s=100)
plt.savefig("Dispersión.jpg")

# %% [markdown]
# Desde acá arranca el entrenamiento de los distintos modelos

# %%
#Regresión lineal

X = data.drop(columns="Price")
y = data["Price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 48)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1019, 20)
# (1019,)
# (340, 20)
# (340,)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.3800677418226108

# %%
y_pred_train = model_lr.predict(X_train)
r2_score(y_train,y_pred_train)
# Out:
# 0.598529009183548

# %%
model_lr.intercept_
# Out:
# 118.35558554390218

# %%
model_lr_intercept_false = LinearRegression(fit_intercept = False)

# %%
model_lr_intercept_false.fit(X_train, y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
y_pred_intercept = model_lr_intercept_false.predict(X_test)
r2_score(y_test,y_pred_intercept)
# Out:
# 0.3800677418226144

# %%
#KNN

model_knn = KNeighborsRegressor()
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn = model_knn.predict(X_test)
r2_score(y_test,y_pred_knn)
# Out:
# 0.3336334109032927

# %%
y_pred_TrainKnn = model_knn.predict(X_train)
r2_score(y_train,y_pred_TrainKnn)
# Out:
# 0.6337479681215015

# %%
model_knn_8neighbors = KNeighborsRegressor(n_neighbors = 8)

# %%
model_knn_8neighbors.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
y_pred_knn8 = model_knn_8neighbors.predict(X_test)
r2_score(y_test,y_pred_knn8)
# Out:
# 0.35597300511688046

# %%
#Estandarización de Datos
scaler = StandardScaler()

# %%
#Estandarizacion con Media y Desvio Estandar
scaler.fit(X_train)
X_train_std = scaler.transform(X_train)
X_train_std
# Out:
# array([[ 1.18297507, -0.44315236,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [ 0.5051153 ,  1.3179023 ,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [-1.18953415, -0.44315236,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        ...,
#        [-1.07655752, -0.44315236,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [ 0.05320878,  0.28455618,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [-1.30251078, -1.1708609 ,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ]])

# %%
X_test_std = scaler.transform(X_test)
X_test_std
# Out:
# array([[ 0.39213867,  0.57563959,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [ 1.26205871,  0.28455618,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [ 0.39213867,  0.28455618,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        ...,
#        [ 1.18297507, -0.44315236,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [ 1.18297507,  1.57987738,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ],
#        [-0.17274448, -0.15206895,  0.10916311, ..., -0.1263018 ,
#         -0.10446386, -0.1180269 ]])

# %%
r2_knn_estandarizado_std = []
for k in range(4,10):
    knn_n= KNeighborsRegressor(n_neighbors=k)
    knn_n.fit(X_train_std, y_train)
    y_pred_n = knn_n.predict(X_test_std)
    r2_knnn = r2_score(y_test,y_pred_n)
    r2_knn_estandarizado_std.append(r2_knnn)
    print("el R2 del modelo con con variables estandarizadas con StandarScaler y", k, "vecinos más cercanos es ", r2_knnn)
# Out:
# el R2 del modelo con con variables estandarizadas con StandarScaler y 4 vecinos más cercanos es  0.4202317868913329
# el R2 del modelo con con variables estandarizadas con StandarScaler y 5 vecinos más cercanos es  0.4561829927247223
# el R2 del modelo con con variables estandarizadas con StandarScaler y 6 vecinos más cercanos es  0.498362755776279
# el R2 del modelo con con variables estandarizadas con StandarScaler y 7 vecinos más cercanos es  0.5023822592769103
# el R2 del modelo con con variables estandarizadas con StandarScaler y 8 vecinos más cercanos es  0.49921940435965884
# el R2 del modelo con con variables estandarizadas con StandarScaler y 9 vecinos más cercanos es  0.4992477974115771

# %%
#Estandarización con Min/Max
scaler_minmax = MinMaxScaler()

# %%
X_train_smm = scaler_minmax.fit_transform(X_train)
X_train_smm
# Out:
# array([[0.5991984 , 0.53061224, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.47895792, 0.77755102, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.17835671, 0.53061224, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.19839679, 0.53061224, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.3987976 , 0.63265306, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.15831663, 0.42857143, 1.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
X_test_smm = scaler.transform(X_test)

# %%
r2_knn_estandarizado_smn = []

for k in range(4,10):
    knn_n= KNeighborsRegressor(n_neighbors=k)
    knn_n.fit(X_train_smm, y_train)
    y_pred_n = knn_n.predict(X_test_smm)
    r2_knnn = r2_score(y_test,y_pred_n)
    r2_knn_estandarizado_smn.append(r2_knnn)
    print("el R2 del modelo con con variables normalizadas con MinMaxScaler y", k, "vecinos más cercanos es ", r2_knnn)
# Out:
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 4 vecinos más cercanos es  -2.0320863034383474
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 5 vecinos más cercanos es  -1.408827046390296
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 6 vecinos más cercanos es  -1.4039924202102334
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 7 vecinos más cercanos es  -1.2345717813009522
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 8 vecinos más cercanos es  -0.9955997959271572
# el R2 del modelo con con variables normalizadas con MinMaxScaler y 9 vecinos más cercanos es  -0.7438934140948494

# %%
knn_7 = KNeighborsRegressor(n_neighbors=7)
knn_7.fit(X_train_std, y_train)
y_pred_7 = knn_7.predict(X_test_std)
r2_knn7 = r2_score(y_test,y_pred_7)

# %%
#Decision Tree
model_dt = DecisionTreeRegressor(random_state = 48)
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=48)

# %%
y_pred_dt = model_dt.predict(X_test)
r2_score(y_test,y_pred_dt)
# Out:
# -0.07369549968432221

# %%
model_dt.get_depth()
# Out:
# 26

# %%
regresion_lineal = r2_score(y_test,y_pred)
knn = r2_score(y_test,y_pred_knn)
arbol_decision = r2_score(y_test,y_pred_dt)

# %%
data
# Out:
#       Battery capacity (mAh)  Screen size (inches)  Touchscreen  Resolution x  \
# 0                       4085                  6.67            1          1440
# 1                       4000                  6.50            1          1080
# 2                       3969                  6.50            1          1242
# 3                       3110                  6.10            1           828
# 4                       4000                  6.40            1          1080
# ...                      ...                   ...          ...           ...
# 1354                    1500                  4.00            1           480
# 1355                    2000                  5.00            1           480
# 1356                    1700                  4.50            1           480
# 1357                    1250                  4.00            1           480
# 1358                    2150                  5.00            1           480
#
#       Resolution y  Processor  RAM (MB)  Internal storage (GB)  Rear camera  \
# 0             3120          8     12000                256.000         48.0
# 1             2400          8      6000                 64.000         64.0
# 2             2688          6      4000                 64.000         12.0
# 3             1792          6      4000                 64.000         12.0
# 4             2340          8      6000                128.000         12.0
# ...            ...        ...       ...                    ...          ...
# 1354           800          4       512                  8.000          5.0
# 1355           854          4      1000                  8.000          8.0
# 1356           854          2       512                  4.000          5.0
# 1357           800          1       256                  0.512          2.0
# 1358           854          4      1000                  8.000          8.0
#
#       Front camera  ...  Bluetooth  GPS  Number of SIMs  3G  4G/ LTE  \
# 0             16.0  ...          1    1               2   1        1
# 1             16.0  ...          1    1               2   1        1
# 2             12.0  ...          1    1               2   1        1
# 3             12.0  ...          1    1               2   1        1
# 4             32.0  ...          1    1               1   0        0
# ...            ...  ...        ...  ...             ...  ..      ...
# 1354           0.3  ...          1    1               2   1        0
# 1355           5.0  ...          1    1               2   1        0
# 1356           2.0  ...          1    0               2   1        0
# 1357           0.3  ...          1    1               2   1        0
# 1358           0.0  ...          1    1               2   1        0
#
#          Price  OS_Android  OS_Others  OS_Windows  OS_iOS
# 0      707.976           1          0           0       0
# 1      335.988           1          0           0       0
# 2     1282.800           0          0           0       1
# 3      754.800           0          0           0       1
# 4      599.880           1          0           0       0
# ...        ...         ...        ...         ...     ...
# 1354    31.188           1          0           0       0
# 1355    35.280           1          0           0       0
# 1356    35.988           1          0           0       0
# 1357    29.976           1          0           0       0
# 1358    47.988           1          0           0       0
#
# [1359 rows x 21 columns]

# %%
r2_dt_depth = []

for a in range(2,15):
    model_dt_depth = DecisionTreeRegressor(random_state = 48, max_depth= a)
    model_dt_depth.fit(X_train, y_train)
    y_pred_dt_depth = model_dt_depth.predict(X_test)
    r2_dt = r2_score(y_test,y_pred_dt_depth)
    r2_dt_depth.append(r2_dt)
    print("el R2 del modelo Arbol de Decision con profundidad ", a, " es ", r2_dt)
# Out:
# el R2 del modelo Arbol de Decision con profundidad  2  es  0.22036694497585163
# el R2 del modelo Arbol de Decision con profundidad  3  es  0.31961367489716075
# el R2 del modelo Arbol de Decision con profundidad  4  es  0.4352752733325739
# el R2 del modelo Arbol de Decision con profundidad  5  es  0.39493831560530046
# el R2 del modelo Arbol de Decision con profundidad  6  es  0.3322274882408479
# el R2 del modelo Arbol de Decision con profundidad  7  es  0.2114611856129518
# el R2 del modelo Arbol de Decision con profundidad  8  es  0.0003523311615868385
# el R2 del modelo Arbol de Decision con profundidad  9  es  0.11127268300950977
# el R2 del modelo Arbol de Decision con profundidad  10  es  -0.08650619088872902
# el R2 del modelo Arbol de Decision con profundidad  11  es  -0.025698458128327717
# el R2 del modelo Arbol de Decision con profundidad  12  es  -0.004829153077906989
# el R2 del modelo Arbol de Decision con profundidad  13  es  0.0689938055834518
# el R2 del modelo Arbol de Decision con profundidad  14  es  0.040555647177558996

# %%
dt_4 = DecisionTreeRegressor(random_state = 48, max_depth=4)
dt_4.fit(X_train, y_train)
y_pred_dt4 = dt_4.predict(X_test)
model_dt_depth4 = r2_score(y_test,y_pred_dt4)

# %%
model_dt_depth4
# Out:
# 0.4352752733325739

# %%
print("La precision medida con R2 de Regresion lineal es", round(regresion_lineal, 2))
print("La precision medida con R2 de KNN es", round(knn, 2))
print("La precision medida con R2 de KNN con datos estandarizados y 7 vecinos es", round(r2_knn7, 2))
print("La precision medida con R2 de Arbol de Decisión es", round(arbol_decision, 2))
print("La precision medida con R2 de Arbol de Decisión con profundidad 4 es", round(model_dt_depth4, 2))
# Out:
# La precision medida con R2 de Regresion lineal es 0.38
# La precision medida con R2 de KNN es 0.33
# La precision medida con R2 de KNN con datos estandarizados y 7 vecinos es 0.5
# La precision medida con R2 de Arbol de Decisión es -0.07
# La precision medida con R2 de Arbol de Decisión con profundidad 4 es 0.44

# %% [markdown]
# Podemos concluir que el modelo con mayor precisión es KNN con datos estandarizados y 7 vecinos.
